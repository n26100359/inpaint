# %%
import util

xtrain, xtest, ytrain, ytest = util.load_cifar10()
print(xtest.shape, ytest.shape)
# Out:
# Using TensorFlow backend.
# (10000, 32, 16, 3) (10000, 32, 16, 3)

# %%
util.plotter(xtest[10:20], ytest[10:20], model_dirs=[
    'gt',
    'models/GAN_cifar_v2/GAN_batch200_diter10_giter1_fake2False/G_10000.hdf5',
    'models/GAN_cifar_v2/GAN_batch200_diter10_giter1_fake2False/G_50000.hdf5',
], rgb=True, figsize=(20,20))
# Out:
# "gt" prediction done.
# "models/GAN_cifar_v2/GAN_batch200_diter10_giter1_fake2False/G_10000.hdf5" prediction done.
# "models/GAN_cifar_v2/GAN_batch200_diter10_giter1_fake2False/G_50000.hdf5" prediction done.
